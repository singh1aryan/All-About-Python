# %%
print(5)
# Out:
# 5

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1,2,3]
y = [1,4,9]
plt.plot(x,y)
plt.title('graph 1')
plt.show()

# %%
x = [1,2,3]
y = [1,4,9]
plt.plot(x,y)
plt.title('graph 1')
plt.show()

# %%
x = [1,2,3]
y = [1,4,9]
z = [2,3,4]
plt.plot(x,y)
plt.title('plot 1')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x = [1,2,3]
y = [1,4,9]
z = [2,3,4]
plt.plot(x,y)
plt.plot(x,z)
plt.title('plot 1')
plt.xlabel('x')
plt.ylabel('y and z')
plt.show()

# %%
x = [1,2,3]
y = [1,4,9]
z = [2,3,4]
plt.plot(x,y)
plt.plot(x,z) 
# y and z
plt.title('plot 1')
plt.xlabel('x')
plt.ylabel('y and z')
plt.legend(["This is y", "This is z"]) 
# legend takes in a list and adds it
plt.show()
